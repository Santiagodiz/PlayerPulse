# %%
import pandas as pd

# %%
df = pd.read_csv('raw/player_stats/Ferran_Torres_data.csv')
df.head()
# Out:
#         Fecha  Día                                Competencia  \
# 0  2023-08-20  Dom                                    La Liga
# 1  2023-08-27  Dom                                    La Liga
# 2  2023-09-03  Dom                                    La Liga
# 3  2023-09-12  Mar  Clasificación para la Eurocopa de la UEFA
# 4  2023-09-16  Sáb                                    La Liga
#
#                  Ronda      Sedes Resultado     Equipo  Adversario Arranque  \
# 0  Semana 2 de partido      Local     V 2–0  Barcelona       Cádiz       No
# 1  Semana 3 de partido  Visitante     V 4–3  Barcelona  Villarreal       No
# 2  Semana 4 de partido  Visitante     V 2–1  Barcelona     Osasuna       No
# 3       Etapa de grupo      Local     V 6–0  es España   cy Chipre       No
# 4  Semana 5 de partido      Local     V 5–0  Barcelona       Betis       Sí
#
#   Posición  ...  Faltas cometidas  Faltas recibidas  Posición adelantada  \
# ...

# %%
for c in df.columns:
    print(c)
# Out:
# Fecha
# Día
# Competencia
# Ronda
# Sedes
# Resultado
# Equipo
# Adversario
# Arranque
# Posición
# Minutos
# Goles
# Asistencias
# Tiros penales ejecutados
# Tiros penales intentados
# Total de disparos
# Lanzamientos en el Objetivo
# Tarjetas amarillas
# Tarjetas rojas
# Toques
# Derribos
# Intercepciones
# Bloqueos
# xG: Goles esperados
# npxG: Goles esperados (xG) sin contar penaltis
# xAG: Exp. Objetivos asistidos
# Acciones para la creación de tiros
# Acciones para la creación de goles
# Pases completados
# Pases intentados
# % de pase completo
# Pases progresivos
# Transportes
# Acarreos progresivos
# Tomas intentadas
# Tomas exitosas
# Informe del partido
# Distancia total de pase
# Distancia de paso progresiva
# Pases completados (Cortos)
# Pases intentados (Cortos)
# % de pase completo (Cortos)
# Pases completados (Medios)
# Pases intentados (Medios)
# % de pase completo (Medios)
# Pases completados (Largos)
# Pases intentados (Largos)
# % de pase completo (Largos)
# ...

# %%
stats = df.columns[10:]
stats
# Out:
# Index(['Minutos', 'Goles', 'Asistencias', 'Tiros penales ejecutados',
#        'Tiros penales intentados', 'Total de disparos',
#        'Lanzamientos en el Objetivo', 'Tarjetas amarillas', 'Tarjetas rojas',
#        'Toques',
#        ...
#        'Faltas cometidas', 'Faltas recibidas', 'Posición adelantada',
#        'Penales ejecutados', 'Penales concedidos', 'Goles en contra',
#        'Recuperación de pelotas', 'Aéreos Ganados', 'Aéreos Perdidos',
#        '% of Aerials Won'],
#       dtype='object', length=108)

# %%
# Formula para calcular el rendimiento de un jugador en un partido
# Rendimiento = (Goles*100 + Asistencias*100 + Tiros a puerta*10 + Tiros fuera*5 + Pases buenos*5 + Pases malos*(-5) + Balones recuperados*10 + Balones perdidos*(-10) + Faltas cometidas*(-10) + Faltas recibidas*10 + Tarjetas amarillas*(-15) + Tarjetas rojas*(-25) + Penaltis fallados*(-50) + Penaltis metidos*50 + Paradas*10 + Goles en propia puerta*(-100) + Penaltis parados*50 + Penaltis encajados*(-50) + Minutos jugados*1) / Minutos jugados

def calculate_performance(df):
    performance = 0
    performance += df['Goles']*100
    performance += df['Asistencias']*100
    performance += df['Total de disparos']*100
    performance += df['Lanzamientos en el objetivo']*100
    performance += df['Tarjetas amarillas']*100
    performance += df['Tarjetas rojas']*100
    performance += df['Toques']*100
    performance += df['Derribos']*100
    performance += df['Intercepciones']*100
    performance += df['Bloqueos']*100
    performance += df['xG: Goles esperados']*100
    performance += df['Asistencias']*100
    performance += df['Asistencias']*100
    performance += df['Asistencias']*100

# %%
# Definir las ponderaciones según las categorías
ponderaciones = {
    'Goles': 0.20,
    'Asistencias': 0.10,
    'Total de disparos': 0.07,
    'Lanzamientos en el Objetivo': 0.05,
    'Tiros penales ejecutados': 0.03,
    'Acciones para la creación de tiros': 0.05,
    'Acciones para la creación de goles': 0.05,
    'xG: Goles esperados': 0.05,
    'npxG: Goles esperados (xG) sin contar penaltis': 0.03,
    'Pases clave': 0.04,
    'Pases en el último tercio de la cancha': 0.03,
    'Pases al área de penalización': 0.02,
    'Cruce en el área de penalización': 0.02,
    'Pases completados': 0.05,
    'Pases intentados': 0.03,
    '% de pase completo': 0.03,
    'Pases progresivos': 0.05,
    'Distancia total de pase': 0.02,
    'Distancia de paso progresiva': 0.02,
    'Pases de Balón Vivo': 0.02,
    'Pases largos': 0.02,
    'Cambios': 0.02,
    'xAG: Exp. Objetivos asistidos': 0.03,
    'Pases de Balón Muerto': 0.02,
    'Pases de tiros libres': 0.02,
    'Saques de esquina': 0.02,
    'Derribos': 0.10,
    'Intercepciones': 0.08,
    'Bloqueos': 0.05,
    'Despeje': 0.08,
    'Errores': -0.05,
    'Goles en contra': -0.05,
    'Recuperación de pelotas': 0.10,
    'Disparos bloqueados': 0.03,
    'Regateadores tackleados': 0.03,
    'Aéreos Ganados': 0.05,
    'Aéreos Perdidos': -0.03,
    '% of Aerials Won': 0.03,
    'Tkl+Int': 0.04,
    'Minutos': 0.05,
    'Toques': 0.03,
    'Faltas cometidas': -0.02,
    'Tarjetas amarillas': -0.03,
    'Tarjetas rojas': -0.10,
    'Transportes': 0.05,
    'Acarreos progresivos': 0.05,
    'Distancia total de traslados': 0.02,
    'Distancia de traslado progresivo': 0.03,
    'Traslados en el último tercio': 0.03,
    'Traslados al área de penal': 0.02,
    'Errores de control': -0.02,
    'Despojado': -0.02,
}

# Función para calcular el rendimiento de cada fila
def calcular_rendimiento(fila, ponderaciones):
    rendimiento = 0
    for estadistica, peso in ponderaciones.items():
        if estadistica in fila:
            rendimiento += fila[estadistica] * peso if pd.notnull(fila[estadistica]) else 0
    return rendimiento

# Aplicar la función a cada fila del DataFrame para calcular el rendimiento
# df['Rendimiento'] = df.apply(lambda fila: calcular_rendimiento(fila, ponderaciones), axis=1)

# # Mostrar los primeros resultados
# print(df[['Minutos', 'Goles', 'Asistencias', 'Rendimiento']].head())

# # Guardar el archivo CSV con la columna de rendimiento
# df.to_csv('/ruta/del/archivo/Ferran_Torres_data_con_rendimiento.csv', index=False)

# %%
calcular_rendimiento(df.iloc[0], ponderaciones)
# Out:
# 4.622

# %%
{
    "Minutos": 1,
    "Goles": 1,
    "Asistencias": 1,
    "Tiros penales ejecutados": 1,
    "Total de disparos": 1,
    "Lanzamientos en el Objetivo": 1,
    "Tarjetas amarillas": 1,
    "Tarjetas rojas": 1,
    "Toques": 1,
    "Derribos": 1,
    "Intercepciones": 1,
    "Bloqueos": 1,
    "xG: Goles esperados": 1,
    "npxG: Goles esperados (xG) sin contar penaltis": 1,
    "Acciones para la creación de tiros": 1,
    "Acciones para la creación de goles": 1,
    "Pases completados": 1,
    "Pases intentados": 1,
    "% de pase completo": 1,
    "Pases progresivos": 1,
    "Transportes": 1,
    "Acarreos progresivos": 1,
    "Tomas intentadas": 1,
    "Tomas exitosas": 1,
    "Pases completados (Cortos)": 1,
    "Pases intentados (Cortos)": 1,
    "% de pase completo (Cortos)": 1,
    "Pases completados (Medios)": 1,
    "Pases intentados (Medios)": 1,
    "% de pase completo (Medios)": 1,
    "Pases completados (Largos)": 1,
    "Pases intentados (Largos)": 1,
    "% de pase completo (Largos)": 1,
    "xA: Asistencias Esperadas": 1,
    "Pases clave": 1,
    "Pases en el último tercio de la cancha": 1,
    "Pases al área de penalización": 1,
    "Cruce en el área de penalización": 1,
    "Pases largos": 1,
    "Cambios": 1,
    "Pases cruzados": 1,
    
    
    "Pases fuera de juego": 1,
    "Pases bloqueados": 1,
    "ACT (Pase de Bal\u00f3n Vivo)": 1,
    "ACT (Pase de Bal\u00f3n Muerto)": 1,
    "ACT (Toma)": 1,
    "ACT (Tiro)": 1,
    "ACT (Faltas recibidas)": 1,
    "ACT (Acci\u00f3n Defensiva)": 1,
    "ACG (Pase de Bal\u00f3n Vivo)": 1,
    "ACG (Pase de Bal\u00f3n Muerto)": 1,
    "ACG (Toma)": 1,
    "ACG (Tiro)": 1,
    "ACG (Faltas recibidas)": 1,
    "ACG (Acci\u00f3n Defensiva)": 1,
    "Derribos conseguidos": 1,
    "Derribos (3.\u00ba def.)": 1,
    "Derribos (3.\u00ba cent.)": 1,
    "Derribos (3.\u00ba ataq.)": 1,
    "Regateadores tackleados": 1,
    "Regateos desafiados": 1,
    "% de Dribladores Derribados": 1,
    "Desaf\u00edos perdidos": 1,
    "Disparos bloqueados": 1,
    "Tkl+Int": 1,
    "Despeje": 1,
    "Errores": 1,
    "Toques (Def. pen.)": 1,
    "Toques (3.\u00ba def.)": 1,
    "Toques (3.\u00ba cent.)": 1,
    "Toques (3.\u00ba ataq.)": 1,
    "Toques (Ataq. pen.)": 1,
    "Toques (Pelota activa)": 1,
    "% de toma exitosa": 1,
    
    "Distancia total de traslados": 1,
    "Distancia de traslado progresivo": 1,
    "Traslados en el \u00faltimo tercio": 1,
    "Traslados al \u00e1rea de penal": 1,
    "Errores de control": 1,
    "Despojado": 1,
    "Pases recibidos": 1,
    "Pases progresivos Rec": 1,
    "Segunda tarjeta amarilla": 1,
    "Faltas cometidas": 1,
    "Faltas recibidas": 1,
    "Posici\u00f3n adelantada": 1,
    "Penales ejecutados": 1,
    "Penales concedidos": 1,
    "Goles en contra": 1,
    "Recuperaci\u00f3n de pelotas": 1,
    
    "% of Aerials Won": 1
}
